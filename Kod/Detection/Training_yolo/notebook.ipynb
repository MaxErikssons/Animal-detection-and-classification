# %% [markdown]
# ## Preparation

# %% [markdown]
# # Install ultralytics

# %%
# Run in terminal
# pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.6 🚀 Python-3.11.3 torch-2.1.2+cpu CPU (Intel Core(TM) i5-8300H 2.30GHz)
# Setup complete ✅ (8 CPUs, 31.9 GB RAM, 51.0/931.5 GB disk)

# %% [markdown]
# ## Custom Training

# %%
#Run in terminal
# Replace model with model you wish to use. (yolov5 / yolov8)
# data.yaml stores the path to training/validation data. 
# specify number of epochs, batch, name...
# yolo task=detect mode=train model=yolov5s.pt data=data.yaml epochs=2 imgsz=640 plots=True name='yolov5'
# https://docs.ultralytics.com/modes/train/

yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=2 imgsz=640 plots=True name='yolov8'

# %%
from IPython.display import Image
Image(filename='runs/detect/yolov8/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/yolov8/results.png', width = 600)

# %% [markdown]
# ## Validation

# %%
#Run in terminal
# Specify model (train) folder
# yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# https://docs.ultralytics.com/modes/val/
# Out:
# Ultralytics YOLOv8.1.6 🚀 Python-3.11.3 torch-2.1.2+cpu CPU (Intel Core(TM) i5-8300H 2.30GHz)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#                    all         29         27      0.435      0.278      0.495      0.388
#                   bear         29         18       0.87      0.556      0.633      0.462
#              wolverine         29          9          0          0      0.356      0.314
# Speed: 2.2ms preprocess, 329.6ms inference, 0.0ms loss, 33.0ms postprocess per image
# Results saved to runs\detect\val
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning D:\Exjobb\Kod\testar\train_data\labels\val.cache... 27 images, 2 backgrounds, 0 corrupt: 100%|██████████| 29/29 [00:00<?, ?it/s]
# val: Scanning D:\Exjobb\Kod\testar\train_data\labels\val.cache... 27 images, 2 backgrounds, 0 corrupt: 100%|██████████| 29/29 [00:00<?, ?it/s]
#
# ...

# %% [markdown]
# ## Predict

# %%
#Run in terminal
#Specify model (train) folder and test data folder
# yolo task=detect mode=predict model=runs/detect/train/weights/best.pt data=data.yaml source=test_data conf=0.25 save=True save_crop=True show_labels=False
# https://docs.ultralytics.com/modes/predict/
# Out:
# Ultralytics YOLOv8.1.6 🚀 Python-3.11.3 torch-2.1.2+cpu CPU (Intel Core(TM) i5-8300H 2.30GHz)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/2 (1/149) d:\Exjobb\Kod\testar\test_data\4354_20210608 (44)_Jerv bærer elgben.MP4: 384x640 5 bears, 1 wolverine, 255.4ms
# video 1/2 (2/149) d:\Exjobb\Kod\testar\test_data\4354_20210608 (44)_Jerv bærer elgben.MP4: 384x640 4 bears, 1 wolverine, 294.9ms
# video 1/2 (3/149) d:\Exjobb\Kod\testar\test_data\4354_20210608 (44)_Jerv bærer elgben.MP4: 384x640 3 bears, 1 wolverine, 245.9ms
# video 1/2 (4/149) d:\Exjobb\Kod\testar\test_data\4354_20210608 (44)_Jerv bærer elgben.MP4: 384x640 4 bears, 1 wolverine, 251.8ms
# video 1/2 (5/149) d:\Exjobb\Kod\testar\test_data\4354_20210608 (44)_Jerv bærer elgben.MP4: 384x640 5 bears, 1 wolverine, 270.3ms
# video 1/2 (6/149) d:\Exjobb\Kod\testar\test_data\4354_20210608 (44)_Jerv bærer elgben.MP4: 384x640 4 bears, 256.6ms
# ...
